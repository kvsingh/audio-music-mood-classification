# %%
import sys

import numpy as np
import pandas as pd
import datetime
import time

# music api imports
import spotipy
import spotipy.util as util
#import billboard
import pygn
#import pylast

import requests
import re
#from bs4 import BeautifulSoup
from time import sleep
import pickle

import matplotlib.pyplot as plt
#import seaborn as sns
# %matplotlib inline

# %%
# timing function
def timefunc(f):
    def f_timer(*args, **kwargs):
        start = time.time()
        result = f(*args, **kwargs)
        end = time.time()
        print f.__name__, 'took', end - start, 'seconds'
        return result
    return f_timer

# %%
clientid = '1308401701-1F1671C0AB98DDAE9637513FCC0366E1'

# %%
userid = pygn.register(clientid)

# %%
# Setting up tokens and authorization - hidden for github, use own tokens

# Spotify
token = util.prompt_for_user_token(<INSERT SPOTIFY USERNAME>,
                                   client_id=<INSERT SPOTIFY CLIENT ID>,
                                   client_secret=<INSERT SPOTIFY CLIENT SECRET>,
                                   redirect_uri=<INSERT REDIRECT URI>)

spotify = spotipy.Spotify(auth=token)

# Gracenote
clientid=<INSERT GRACENOTE CLIENTID>
userid = pygn.register(clientid)

# last.fm
apikey = <INSERT LASTFM API KEY>
apisecret = <INSERT LASTFM API SECRET>
username = <INSERT YOUR USERNAME>
password_hash = pylast.md5(<INSERT YOUR PASSWORD>)

lastfm = pylast.LastFMNetwork(api_key = apikey, api_secret = apisecret,
                               username = username, password_hash = password_hash)

# %%
songs = pd.read_pickle('data/spotify_songs.pkl')

# %%
songs
# Out:
#                                                artist explicit  \
# 0                                             Nirvana    False
# 1      The Presidents Of The United States Of America    False
# 2                                       Joshua Hyslop    False
# 3                                   John Joseph Brill    False
# 4                                   Danielle Bradbery    False
# 5                                             TAEYEON    False
# 6                                               Faker    False
# 7                                           Sir Spyro    False
# 8                                              N.W.A.     True
# 9                                          Katchafire    False
# 10                                       Lupe Fuentes    False
# 11                               Kenny Wayne Shepherd    False
# 12                                              Robyn    False
# 13                                 BJ The Chicago Kid    False
# 14                                             Laylow    False
# 15                                         Tim Legend    False
# 16                                        Andrew W.K.    False
# 17                                          Pearl Jam    False
# 18                                          Alborosie    False
# 19                                        Julie Byrne    False
# 20                                           Sam Hunt    False
# 21                                      George Carlin    False
# 22                    Tom Petty and the Heartbreakers    False
# 23                                     Human Fortress    False
# 24                                             Kaftan    False
# 25                                        Kail Baxley    False
# 26                                          Dirty Mac    False
# 27                                      Achille Lauro    False
# 28                                       Mallory Knox    False
# 29                                            Fat Jon    False
# ...                                               ...      ...
# 36066                                     Fossa Beats    False
# 36067                                  Brandi Carlile    False
# 36068                                     Cosmic Gate    False
# 36069                                         Pitbull    False
# 36070                                    Juana Molina    False
# 36071                                     Tame Impala    False
# 36072                                  La Insuperable    False
# 36073                                    Tori Forsyth    False
# 36074                                       Luc Serra    False
# 36075                                   Joseph Barnby    False
# 36076                                   Jean Sibelius    False
# 36077                                   Howard Hanson    False
# 36078                                         Dubchek    False
# 36079                                        The Cars    False
# 36080                                        CHVRCHES    False
# 36081                                     Bob Sinclar    False
# 36082                                            Samo    False
# 36083                                    The Limianas    False
# 36084                                          Samiam    False
# 36085                                     Polographia    False
# 36086                                      The Strike    False
# 36087                                         Belocca    False
# 36088                                     Major Lazer    False
# 36089                                   Mourning Dove    False
# 36090                                   Carlos Rivera    False
# 36091                                        The Frim    False
# 36092                                         Shallou    False
# 36093                                   Henry Jamison    False
# 36094                                   Songhoy Blues    False
# 36095                                            DEVO    False
#
#                            id  popularity  \
# 0      3FUsMXBxA4V7eUwQ7B0HQO          56
# 1      2JdzB67NvIa90K4gEZPLeX          67
# 2      5nhptWSQJ8WRqHGJDJXrPM          49
# 3      4y9zPQF2PHpVFPVR20nbcY           6
# 4      5APWbHdwUCA08ZLl0meDCh          60
# 5      6CdUgvL597jWmW4w8P5kHs          62
# 6      2HwlvOkwACOGFySnp16b9l          48
# 7      08rB1AFgNC3e4UUjvC9Zel          60
# 8      7MMfKdXKwnnZBT8vIuCvLs          57
# 9      3BojnSbIR2oKctO3nvBLRb          52
# 10     3GcUj8auLXiSbZ77nnbI8w          28
# 11     0PnyMytBrk2X9T5pYmati9          10
# 12     01NJd6s7Kyn6NSsPp503sh          29
# 13     17mmoof9SycaS0kKRcK0mt          44
# 14     0GguM9B0CZBoriefiHhxBz           3
# 15     1OS490EO5cVK5ht55dLlB3          57
# 16     3RNuruayCGWg2B6K9Qxya8          52
# 17     6qgpO647NPBUvBkm56vV7d           8
# 18     2LfjfCgBzafdPlBtmUlKev           1
# 19     6AX0iXa7ZrvLZBsvmES6h8          39
# 20     3wx2kQWPn9p5UppQbNhPAk          69
# 21     5DuxYjcuebFPontojL1NEE           0
# 22     2OECBjmrt1tupVdg8jcfE1          48
# 23     0gKISkC4SwxBmMJ8eQTDGF          36
# 24     7fRr8M0BGE3mmf9rjKcjd0          33
# 25     3zkdaLqbeTXcIyJnMAwA35          31
# 26     1mT4MwmdVPHvcqAkYyFg9C          43
# 27     1YTw1eDNxBn0sO78sDPkvr          71
# 28     71H2SB2sNLUuGvZ8iV02cT          50
# 29     5o6WCwKNByv0py1w1zuKw0          13
# ...                       ...         ...
# 36066  2FG1ayvioaTgtj8dhcZGCV          60
# 36067  4TWn4YeBaTqDURrYLd6k0a          54
# 36068  37sksUk6rSZBIMxdAzbCgE          39
# 36069  6a8GbQIlV8HBUW3c6Uk9PH          59
# 36070  037RKV3MIa0h2qHDZUR79x          28
# 36071  1hmK18w3PueSkGcMqlfnOX          48
# 36072  6MzPQpBqbIjEJLJ40mltQJ          33
# 36073  6Np6TWCPNqAWdKHKtwPBKM          30
# 36074  6FGg0rf7lCxAgAKK8giasF          55
# 36075  24zWxhxC7eT6ta78jl90Es          19
# 36076  3hHWhvw2hjwfngWcFjIzqr          38
# 36077  22HYjeZNrpSmaGNeo4Vfrw          23
# 36078  3xHKTYLRLdzHrs6uiN72GQ          35
# 36079  4alHo6RGd0D3OUbTPExTHN          69
# 36080  5IzPu8XNwVwl1WHGQMpRww          41
# 36081  2Ua2W5HQsXDPHyQLTQVSNS          40
# 36082  7qTyJeiOcTLJemMaFbYxla          46
# 36083  5Q7dJvHFPECFtCTzbYYrvF          39
# 36084  5GPOoMiSetLAYiV3AqVRwV          39
# 36085  2YNMDVJ2fMHD7wWXW5CNQt          41
# 36086  4jJaLMKevio9DRVo12LUHI           2
# 36087  4AZjrzMMiFSpDwMiCNrE3I          30
# 36088  013amIZ8QjBqviUEM2yNJZ          64
# 36089  4qSKxaLDsyrVk5hcImkpIt          45
# 36090  3KBtQE1nRncJf51JbOxYDE          21
# 36091  74lWFSsE1jW3TsIKvWZ96F          14
# 36092  3a1DVjwshmHW9DR7pJMTaR          54
# 36093  5Wvf91821sBE8aErRtpfRN          23
# 36094  1oSip9aq8h5GyJW0t3rcfn          31
# 36095  1RG1Pz45nlYNHka7JioyOT          49
#
#                                                   title  energy  liveness  \
# 0                                Love Buzz - Remastered  0.8850    0.1690
# 1                                                  Lump  0.8730    0.1650
# 2                                     Stand Your Ground  0.2700    0.1150
# 3                                       I'm Not Alright  0.5310    0.0878
# 4                                              Worth It  0.4900    0.1380
# 5                                                  Fine  0.5650    0.0448
# 6                                     This Heart Attack  0.8130    0.1410
# 7                                     Hell to the Liars  0.6090    0.0717
# 8                                              Dope Man  0.7020    0.1230
# 9                                           Love Letter  0.5500    0.0730
# 10                             The Drugs - Original Mix  0.9070    0.1500
# 11                                      Diamonds & Gold  0.8460    0.0464
# 12              Be Mine! - Live At The Cherrytree House  0.2490    0.1140
# 13                                        Turnin' Me Up  0.7680    0.0505
# 14                                                  10'  0.2960    0.2970
# 15                        Telescope (feat. Transviolet)  0.6600    0.1880
# 16                            Music Is Worth Living For  0.9940    0.2680
# 17                                                Black  0.5480    0.1790
# 18                Mama She Don't Like You - feat. I.Eye  0.7480    0.0892
# 19                                         Natural Blue  0.1390    0.0850
# 20                                   Leave The Night On  0.9530    0.3490
# 21                                         War Pictures  0.5460    0.1470
# 22                        A Woman In Love (It's Not Me)  0.5990    0.3500
# 23                                          Dark Knight  0.9610    0.2030
# 24                                     Romance In Dubai  0.1940    0.7230
# 25                            Better Feeln' Better Days  0.4010    0.0943
# 26                                     Yer Blues - Live  0.8740    0.6860
# 27     Thoiry Remix (Samba Trap Vol. 3 - Mitraglia Rec)  0.8020    0.3310
# 28                                                Sugar  0.9770    0.3310
# 29                                        Feel The Void  0.2280    0.1520
# ...                                                 ...     ...       ...
# 36066                                         I Promise  0.4030    0.0705
# 36067                                        Raise Hell  0.7730    0.0972
# 36068                       Tonight - Allen Watts Remix  0.9620    0.3830
# 36069                   I Know You Want Me (Calle Ocho)  0.7430    0.2370
# 36070                                              Eras  0.4760    0.0900
# 36071                           Half Full Glass Of Wine  0.7730    0.0803
# 36072                                   Mastica y Traga  0.6480    0.1100
# 36073                           Grave Robber's Daughter  0.5950    0.2240
# 36074                           Blade Runner Love Theme  0.1220    0.1010
# 36075                                          Psalm 59  0.1170    0.1080
# 36076                                 Finlandia, Op. 26  0.1880    0.0989
# 36077                            The Lament for Beowulf  0.0382    0.1060
# 36078                                  Montella Sail on  0.2050    0.1100
# 36079                                Just What I Needed  0.5790    0.0858
# 36080                   My Enemy (feat. Matt Berninger)  0.5340    0.1020
# 36081                                          Stand Up  0.9910    0.2200
# 36082                                            Eterno  0.5820    0.1250
# 36083          Shadow People (feat. Emmanuelle Seigner)  0.6240    0.1290
# 36084                                          Sunshine  0.9630    0.1420
# 36085                     Sly (feat. Winston Surfshirt)  0.7530    0.1370
# 36086                                             Shame  0.8610    0.1850
# 36087                                 Perpetual Changes  0.9000    0.1180
# 36088                                       Bubble Butt  0.7710    0.6060
# 36089                                     Mourning Dove  0.2280    0.1060
# 36090   Recurdame - De "Coco" / Versin de Carlos Rivera  0.7320    0.3860
# 36091                                  Somebody's Cream  0.9790    0.3200
# 36092                                              Find  0.4680    0.2320
# 36093                                         The Rains  0.3990    0.0704
# 36094                                            Bamako  0.7940    0.0996
# 36095                               Uncontrollable Urge  0.8580    0.0943
#
#          tempo  speechiness  acousticness  instrumentalness  time_signature  \
# 0      138.153       0.0354      0.000032          0.196000               4
# 1      142.726       0.0386      0.004680          0.000000               4
# 2      131.876       0.0283      0.658000          0.000005               4
# 3      100.000       0.0242      0.143000          0.875000               4
# 4      115.020       0.0322      0.272000          0.000000               3
# 5      173.281       0.0608      0.358000          0.000000               4
# 6      122.016       0.0428      0.020100          0.000000               4
# 7      134.916       0.2740      0.081900          0.000000               4
# 8      176.483       0.2710      0.007690          0.000000               4
# 9      145.004       0.0568      0.130000          0.136000               4
# 10     124.008       0.0344      0.000081          0.517000               4
# 11      92.040       0.0339      0.037100          0.000041               4
# 12     116.599       0.0451      0.955000          0.000000               4
# 13      78.488       0.0789      0.051000          0.161000               4
# 14     112.254       0.0668      0.583000          0.000000               4
# 15     111.991       0.0352      0.093900          0.002490               4
# 16     163.962       0.0783      0.000888          0.000045               4
# 17      76.020       0.0287      0.294000          0.000000               4
# 18      98.003       0.0311      0.021300          0.000000               4
# 19     141.441       0.0319      0.938000          0.000012               3
# 20     171.971       0.0624      0.099600          0.000000               4
# 21      72.940       0.9610      0.921000          0.000000               3
# 22     126.524       0.0402      0.022600          0.000031               4
# 23      89.974       0.0791      0.001040          0.000184               4
# 24     123.994       0.0343      0.846000          0.913000               4
# 25     149.920       0.0423      0.110000          0.833000               4
# 26     110.950       0.1320      0.004690          0.127000               4
# 27     123.849       0.2570      0.038600          0.000000               4
# 28     170.207       0.2460      0.000844          0.000060               4
# 29     176.037       0.0682      0.312000          0.830000               4
# ...        ...          ...           ...               ...             ...
# 36066  113.988       0.1020      0.791000          0.000704               4
# 36067  105.946       0.0457      0.228000          0.000007               4
# 36068  137.969       0.2200      0.003670          0.159000               4
# 36069  127.046       0.1410      0.014200          0.000021               4
# 36070  108.016       0.0328      0.822000          0.147000               1
# 36071  126.088       0.0827      0.262000          0.048900               4
# 36072  119.973       0.0878      0.482000          0.003810               4
# 36073  180.408       0.0303      0.227000          0.000005               4
# 36074  139.678       0.0318      0.796000          0.945000               4
# 36075  127.282       0.0420      0.959000          0.094700               5
# 36076   74.637       0.0392      0.933000          0.887000               4
# 36077  142.369       0.0407      0.970000          0.879000               3
# 36078  119.990       0.0440      0.242000          0.790000               4
# 36079  127.224       0.0473      0.015200          0.000064               4
# 36080  133.952       0.0311      0.125000          0.000000               4
# 36081  123.966       0.0450      0.004860          0.855000               4
# 36082  104.967       0.0426      0.032700          0.000000               4
# 36083   93.297       0.0264      0.000124          0.052100               4
# 36084  111.397       0.0497      0.000119          0.197000               4
# 36085  100.017       0.0424      0.136000          0.002490               4
# 36086  163.096       0.0627      0.016200          0.000000               4
# 36087  123.999       0.0991      0.001130          0.805000               4
# 36088  194.072       0.3470      0.011500          0.002370               4
# 36089  110.228       0.0330      0.984000          0.026300               3
# 36090   80.053       0.0378      0.132000          0.000002               4
# 36091  150.032       0.0805      0.000190          0.597000               4
# 36092   92.060       0.0425      0.054000          0.001080               4
# 36093  117.027       0.0280      0.648000          0.016700               4
# 36094  118.551       0.1900      0.032000          0.000063               4
# 36095   92.523       0.0326      0.055100          0.665000               3
#
#        danceability  key  duration_ms  loudness  valence  mode
# 0             0.470    3       215120    -7.224   0.7900     1
# 1             0.499    6       134200    -3.902   0.8640     1
# 2             0.710    7       203253    -9.541   0.6840     1
# 3             0.591    6       214120   -10.889   0.2810     1
# 4             0.544    5       206827    -4.627   0.3840     1
# 5             0.360    7       209157    -4.898   0.3110     1
# 6             0.625    1       227733    -4.184   0.7330     0
# 7             0.568    2       228000    -8.978   0.0712     0
# 8             0.753    7       375733    -7.922   0.7270     1
# 9             0.830    7       214293    -5.367   0.9700     1
# 10            0.684    5       344516    -6.459   0.7860     1
# 11            0.574    8       317773    -5.703   0.7940     1
# 12            0.533    0       272053    -8.532   0.5070     0
# 13            0.741    2       269467    -4.349   0.8240     1
# 14            0.546    4       238064   -20.172   0.2700     0
# 15            0.673    0       175714    -4.740   0.2680     0
# 16            0.463    2       262693    -4.101   0.4150     1
# 17            0.376    4       343667   -10.580   0.2400     0
# 18            0.784    9       239267    -3.659   0.7540     0
# 19            0.280    9       239040   -13.500   0.3170     1
# 20            0.516    9       192160    -3.828   0.8520     1
# 21            0.611    7       222200   -10.444   0.5050     1
# 22            0.567    9       261773    -6.903   0.5720     1
# 23            0.416    5       302782    -4.547   0.2430     0
# 24            0.447   10       459133   -14.445   0.2660     0
# 25            0.764    1       223000    -8.612   0.0716     1
# 26            0.408    8       266600    -8.266   0.7390     1
# 27            0.700    7       174919    -4.637   0.5950     1
# 28            0.300    1       209955    -3.558   0.3790     0
# 29            0.593    6       199877   -15.824   0.6470     0
# ...             ...  ...          ...       ...      ...   ...
# 36066         0.837    8       193696    -9.225   0.4060     1
# 36067         0.652   11       248240    -4.798   0.4350     0
# 36068         0.255    9       196522    -7.455   0.1520     0
# 36069         0.824    2       237120    -5.995   0.8040     1
# 36070         0.746    0       264747   -12.349   0.6350     0
# 36071         0.680    0       266160    -6.915   0.6440     1
# 36072         0.896   10       242832    -7.825   0.7270     0
# 36073         0.369    1       223396    -4.614   0.2870     0
# 36074         0.423    1       253714   -18.076   0.0392     1
# 36075         0.198    5       268933   -25.887   0.0397     0
# 36076         0.181    8       507973   -19.208   0.0410     1
# 36077         0.138    2      1147280   -25.909   0.0348     0
# 36078         0.773    9       256000   -16.298   0.2390     1
# 36079         0.619    4       225627    -9.307   0.6900     1
# 36080         0.557    2       233079    -6.797   0.0726     0
# 36081         0.633    4       177154    -2.657   0.7510     0
# 36082         0.328    1       213453    -6.153   0.3500     1
# 36083         0.472    0       191627    -6.626   0.5040     1
# 36084         0.526    9       196293    -5.889   0.5170     1
# 36085         0.730    5       211200    -7.782   0.6080     0
# 36086         0.458    2       194230    -3.436   0.7910     1
# 36087         0.869   11       512903    -8.886   0.1680     0
# 36088         0.765    7       227813    -6.990   0.3940     1
# 36089         0.584    1       198942   -14.042   0.3250     0
# 36090         0.450    6       163328    -2.221   0.3990     1
# 36091         0.548    1       273600    -1.053   0.3380     1
# 36092         0.550    0       219118    -7.608   0.2930     1
# 36093         0.689    6       211795   -10.906   0.4320     1
# 36094         0.754    4       220133    -7.915   0.9130     0
# 36095         0.571    2       191267    -7.066   0.7160     1
#
# [36096 rows x 18 columns]

# %%
# Get track info from gracenote
# NOTE: Gracenote API has built-in fuzzy matching to artist and track.
from collections import defaultdict

def get_gn_multiple(search, dictionary, item):
    '''
    Helper function to get multiple items within Gracenote record
    '''
    for i in search[item].iteritems():
        dictionary[item + '_' + i[0]] = i[1]['TEXT']

def get_gn(artist, track):
    '''
    Gets artist and track information from Gracenote
    '''
    gn_dict = defaultdict(list)
    gn_info = pygn.search(clientid, userid, artist=artist, track=track)

    gn_dict['gnid'] = gn_info['track_gnid']

    # artist specific info
    for a in ['artist_origin', 'artist_type', 'artist_era']:
        get_gn_multiple(gn_info, gn_dict, a)
    # track specific info
    for s in ['genre', 'mood', 'tempo']: # can potentially drop 'tempo' since Spotify has already captured this
        get_gn_multiple(gn_info, gn_dict, s)      

    return gn_dict['mood_1']

# %%
test
# Out:
#                                            artist explicit  \
# 0                                         Nirvana    False
# 1  The Presidents Of The United States Of America    False
# 2                                   Joshua Hyslop    False
# 3                               John Joseph Brill    False
# 4                               Danielle Bradbery    False
# 5                                         TAEYEON    False
# 6                                           Faker    False
# 7                                       Sir Spyro    False
# 8                                          N.W.A.     True
# 9                                      Katchafire    False
#
#                        id  popularity                   title  energy  \
# 0  3FUsMXBxA4V7eUwQ7B0HQO          56  Love Buzz - Remastered   0.885
# 1  2JdzB67NvIa90K4gEZPLeX          67                    Lump   0.873
# 2  5nhptWSQJ8WRqHGJDJXrPM          49       Stand Your Ground   0.270
# 3  4y9zPQF2PHpVFPVR20nbcY           6         I'm Not Alright   0.531
# 4  5APWbHdwUCA08ZLl0meDCh          60                Worth It   0.490
# 5  6CdUgvL597jWmW4w8P5kHs          62                    Fine   0.565
# 6  2HwlvOkwACOGFySnp16b9l          48       This Heart Attack   0.813
# 7  08rB1AFgNC3e4UUjvC9Zel          60       Hell to the Liars   0.609
# 8  7MMfKdXKwnnZBT8vIuCvLs          57                Dope Man   0.702
# 9  3BojnSbIR2oKctO3nvBLRb          52             Love Letter   0.550
#
#    liveness    tempo  speechiness  acousticness  instrumentalness  \
# 0    0.1690  138.153       0.0354      0.000032          0.196000
# 1    0.1650  142.726       0.0386      0.004680          0.000000
# 2    0.1150  131.876       0.0283      0.658000          0.000005
# 3    0.0878  100.000       0.0242      0.143000          0.875000
# 4    0.1380  115.020       0.0322      0.272000          0.000000
# 5    0.0448  173.281       0.0608      0.358000          0.000000
# 6    0.1410  122.016       0.0428      0.020100          0.000000
# 7    0.0717  134.916       0.2740      0.081900          0.000000
# 8    0.1230  176.483       0.2710      0.007690          0.000000
# 9    0.0730  145.004       0.0568      0.130000          0.136000
#
#    time_signature  danceability  key  duration_ms  loudness  valence  mode
# 0               4         0.470    3       215120    -7.224   0.7900     1
# 1               4         0.499    6       134200    -3.902   0.8640     1
# 2               4         0.710    7       203253    -9.541   0.6840     1
# 3               4         0.591    6       214120   -10.889   0.2810     1
# 4               3         0.544    5       206827    -4.627   0.3840     1
# 5               4         0.360    7       209157    -4.898   0.3110     1
# 6               4         0.625    1       227733    -4.184   0.7330     0
# 7               4         0.568    2       228000    -8.978   0.0712     0
# 8               4         0.753    7       375733    -7.922   0.7270     1
# 9               4         0.830    7       214293    -5.367   0.9700     1

# %%
d = {u'2HwlvOkwACOGFySnp16b9l': 'Yearning', u'08rB1AFgNC3e4UUjvC9Zel': 'Defiant', u'3FUsMXBxA4V7eUwQ7B0HQO': 'Brooding', u'2JdzB67NvIa90K4gEZPLeX': 'Aggressive', u'3BojnSbIR2oKctO3nvBLRb': 'Energizing', u'5nhptWSQJ8WRqHGJDJXrPM': 'Defiant', u'7MMfKdXKwnnZBT8vIuCvLs': 'Cool', u'4y9zPQF2PHpVFPVR20nbcY': 'Sensual', u'5APWbHdwUCA08ZLl0meDCh': 'Empowering', u'6CdUgvL597jWmW4w8P5kHs': 'Sophisticated'}

# %%
p = pd.DataFrame.from_dict(d, 'index')

# %%
p = p.reset_index()

# %%
p.columns = ['id', 'mood']

# %%
p
# Out:
#                        id           mood
# 0  7MMfKdXKwnnZBT8vIuCvLs           Cool
# 1  2HwlvOkwACOGFySnp16b9l       Yearning
# 2  08rB1AFgNC3e4UUjvC9Zel        Defiant
# 3  4y9zPQF2PHpVFPVR20nbcY        Sensual
# 4  5APWbHdwUCA08ZLl0meDCh     Empowering
# 5  3FUsMXBxA4V7eUwQ7B0HQO       Brooding
# 6  2JdzB67NvIa90K4gEZPLeX     Aggressive
# 7  6CdUgvL597jWmW4w8P5kHs  Sophisticated
# 8  3BojnSbIR2oKctO3nvBLRb     Energizing
# 9  5nhptWSQJ8WRqHGJDJXrPM        Defiant

# %%
test_gn_df = append_gn_df(test)
# Out:
# {u'2HwlvOkwACOGFySnp16b9l': 'Yearning', u'08rB1AFgNC3e4UUjvC9Zel': 'Defiant', u'3FUsMXBxA4V7eUwQ7B0HQO': 'Brooding', u'2JdzB67NvIa90K4gEZPLeX': 'Aggressive', u'3BojnSbIR2oKctO3nvBLRb': 'Energizing', u'5nhptWSQJ8WRqHGJDJXrPM': 'Defiant', u'7MMfKdXKwnnZBT8vIuCvLs': 'Cool', u'4y9zPQF2PHpVFPVR20nbcY': 'Sensual', u'5APWbHdwUCA08ZLl0meDCh': 'Empowering', u'6CdUgvL597jWmW4w8P5kHs': 'Sophisticated'}
# append_gn_df took 15.4696218967 seconds

# %%
@timefunc
def append_gn_df(df):
    '''
    Creates dataframe with artist and track information from Gracenote
    '''
    d = {}
    for index, row in df.iterrows():
        #print row['title']
        try:
            d[row['id']] = get_gn(row['artist'], row['title'])
        except:
            pass
    print d
    gn_df = pd.DataFrame.from_dict(d, 'index').reset_index()
    print gn_df
    gn_df.columns = ['id', 'mood']
    #gn_df = pd.DataFrame(d).transpose().reset_index()
    gn_df = gn_df.rename(columns = {'index' : 'id'})
    return gn_df

# %%
@timefunc
def chunk_gn_df(df, start, stop):
    '''
    Gets Gracenote dataframe from dataframe with spotify IDs and merges them, indexing based on Spotify dataframe
    '''
    full_songs = pd.DataFrame()
    for i in range(start, stop, 100): 
        gn = append_gn_df(df[i:i+100])
        data = pd.merge(df, gn, on='id')
        full_songs = full_songs.append(data, ignore_index=True)
        full_songs.to_pickle('data/full_songs_df_' + str(i) + '.pkl')
        sleep(.1)

# %% [markdown]
# ### Testing functions

# %%
test = songs[:10].copy()

# %%
test_gn_df
# Out:
# Empty DataFrame
# Columns: [id]
# Index: []

# %%
test_gn_df = append_gn_df(test)
# Out:
# append_gn_df took 0.0026547908783 seconds

# %%
test2 = songs[:100].copy()

# %%
test_gn_df2 = append_gn_df(test2)
# Out:
# append_gn_df took 78.8128910065 seconds

# %%
test3 = songs[:1000].copy()

# %%
test = chunk_gn_df(test3)
# Out:
# append_gn_df took 79.7802000046 seconds
# append_gn_df took 86.6563389301 seconds
# append_gn_df took 65.2759389877 seconds
# append_gn_df took 79.6878931522 seconds
# append_gn_df took 76.4993541241 seconds
# append_gn_df took 90.4260671139 seconds
# append_gn_df took 72.7159290314 seconds
# append_gn_df took 76.5112099648 seconds
# append_gn_df took 94.4111959934 seconds
# append_gn_df took 79.794656992 seconds
# chunk_gn_df took 802.02742815 seconds

# %% [markdown]
# ## Batch Gracenote API Calls

# %%
## Can be called iteratively; manual process and assignemnt to variables not necessary
full_songs1999 = chunk_gn_df(songs, 1000, 2000)
# Out:
# append_gn_df took 67.4224410057 seconds
# append_gn_df took 72.3883001804 seconds
# append_gn_df took 79.8355090618 seconds
# append_gn_df took 78.1213560104 seconds
# append_gn_df took 80.340474844 seconds
# append_gn_df took 64.7614121437 seconds
# append_gn_df took 79.3378539085 seconds
# append_gn_df took 77.4290459156 seconds
# append_gn_df took 68.3279361725 seconds
# append_gn_df took 84.0087909698 seconds
# chunk_gn_df took 753.381345987 seconds

# %%
full_songs2999 = chunk_gn_df(songs, 2000, 3000)
# Out:
# Must query with at least one field (artist, album, track, toc)
# append_gn_df took 84.309497118 seconds
# append_gn_df took 72.887706995 seconds
# append_gn_df took 96.2273700237 seconds
# append_gn_df took 132.650071144 seconds
# append_gn_df took 85.8785710335 seconds
# append_gn_df took 88.1040289402 seconds
# append_gn_df took 77.864866972 seconds
# append_gn_df took 86.2918081284 seconds
# append_gn_df took 69.6620688438 seconds
# append_gn_df took 68.9744520187 seconds
# chunk_gn_df took 864.217645884 seconds

# %%
full_songs3999 = chunk_gn_df(songs, 3000, 4000)
# Out:
# append_gn_df took 78.3683691025 seconds
# append_gn_df took 79.9486739635 seconds
# append_gn_df took 72.4678637981 seconds
# append_gn_df took 78.1993000507 seconds
# append_gn_df took 72.6659281254 seconds
# append_gn_df took 76.5402870178 seconds
# append_gn_df took 78.0043098927 seconds
# append_gn_df took 73.5283191204 seconds
# append_gn_df took 75.2775919437 seconds
# append_gn_df took 74.0675299168 seconds
# chunk_gn_df took 760.451182127 seconds

# %%
full_songs4999 = chunk_gn_df(songs, 4000, 5000)
# Out:
# append_gn_df took 76.9578900337 seconds
# append_gn_df took 75.7942149639 seconds
# append_gn_df took 73.5237259865 seconds
# append_gn_df took 77.3375658989 seconds
# append_gn_df took 82.8529810905 seconds
# append_gn_df took 67.162250042 seconds
# Must query with at least one field (artist, album, track, toc)
# append_gn_df took 72.9738769531 seconds
# append_gn_df took 71.6249399185 seconds
# Must query with at least one field (artist, album, track, toc)
# append_gn_df took 79.046284914 seconds
# append_gn_df took 71.738476038 seconds
# chunk_gn_df took 750.387325048 seconds

# %%
full_songs5999 = chunk_gn_df(songs, 5000, 6000)
# Out:
# append_gn_df took 95.8282520771 seconds
# append_gn_df took 69.6465280056 seconds
# append_gn_df took 83.172315836 seconds
# append_gn_df took 78.8234639168 seconds
# append_gn_df took 80.6341700554 seconds
# Must query with at least one field (artist, album, track, toc)
# append_gn_df took 68.7922978401 seconds
# append_gn_df took 77.1774830818 seconds
# append_gn_df took 83.2521080971 seconds
# append_gn_df took 69.8379299641 seconds
# append_gn_df took 70.1823079586 seconds
# chunk_gn_df took 778.720597029 seconds

# %%
full_songs6999 = chunk_gn_df(songs, 6000, 7000)
# Out:
# append_gn_df took 86.7909920216 seconds
# append_gn_df took 78.6328549385 seconds
# append_gn_df took 78.0821502209 seconds
# append_gn_df took 74.4237539768 seconds
# append_gn_df took 69.9132301807 seconds
# append_gn_df took 68.4916939735 seconds
# append_gn_df took 79.7115499973 seconds
# append_gn_df took 76.0548529625 seconds
# append_gn_df took 83.470785141 seconds
# append_gn_df took 80.4534299374 seconds
# chunk_gn_df took 777.427739143 seconds

# %%
full_songs7999 = chunk_gn_df(songs, 7000, 8000)
# Out:
# append_gn_df took 87.3198399544 seconds
# append_gn_df took 71.2444541454 seconds
# append_gn_df took 64.7104129791 seconds
# append_gn_df took 91.5900039673 seconds
# append_gn_df took 78.8001978397 seconds
# append_gn_df took 81.8212971687 seconds
# append_gn_df took 78.2230608463 seconds
# append_gn_df took 84.765859127 seconds
# append_gn_df took 82.0997200012 seconds
# append_gn_df took 86.5055379868 seconds
# chunk_gn_df took 808.462280035 seconds

# %%
full_songs8999 = chunk_gn_df(songs, 8000, 9000)
# Out:
# append_gn_df took 77.7793679237 seconds
# append_gn_df took 73.5890009403 seconds
# append_gn_df took 72.8890779018 seconds
# append_gn_df took 76.9375469685 seconds
# append_gn_df took 87.3194820881 seconds
# append_gn_df took 72.121778965 seconds
# append_gn_df took 78.8284990788 seconds
# append_gn_df took 88.3182590008 seconds
# append_gn_df took 64.0786280632 seconds
# append_gn_df took 74.8370850086 seconds
# chunk_gn_df took 768.161731958 seconds

# %%
full_songs9999 = chunk_gn_df(songs, 9000, 10000)
# Out:
# append_gn_df took 76.7856390476 seconds
# append_gn_df took 78.7005288601 seconds
# append_gn_df took 78.9515731335 seconds
# append_gn_df took 75.6537179947 seconds
# append_gn_df took 84.0704278946 seconds
# append_gn_df took 72.4143879414 seconds
# append_gn_df took 125.271933079 seconds
# append_gn_df took 153.4139359 seconds
# append_gn_df took 119.485553026 seconds
# append_gn_df took 308.530214071 seconds
# chunk_gn_df took 1174.64778805 seconds

# %%
full_songs10999 = chunk_gn_df(songs, 10000, 11000)
# Out:
# append_gn_df took 131.71905899 seconds
# append_gn_df took 96.9787621498 seconds
# append_gn_df took 146.209033966 seconds
# append_gn_df took 351.851246119 seconds
# append_gn_df took 154.008980989 seconds
# append_gn_df took 105.124425888 seconds
# append_gn_df took 230.586303949 seconds
# append_gn_df took 112.298628092 seconds
# append_gn_df took 85.2859518528 seconds
# append_gn_df took 110.163626194 seconds
# chunk_gn_df took 1525.60910511 seconds

# %%
full_songs11999 = chunk_gn_df(songs, 11000, 12000)
# Out:
# append_gn_df took 98.8968849182 seconds
# append_gn_df took 97.7458968163 seconds
# append_gn_df took 91.483907938 seconds
# append_gn_df took 107.240098953 seconds
# append_gn_df took 118.474504948 seconds
# append_gn_df took 111.802592039 seconds
# append_gn_df took 343.274796009 seconds
# append_gn_df took 226.170608044 seconds
# append_gn_df took 89.4556779861 seconds
# append_gn_df took 117.234147072 seconds
# chunk_gn_df took 1403.17566109 seconds

# %%
full_songs12999 = chunk_gn_df(songs, 12000, 13000)
# Out:
# append_gn_df took 133.29369092 seconds
# append_gn_df took 151.5761621 seconds
# append_gn_df took 92.5917768478 seconds
# append_gn_df took 149.255569935 seconds
# append_gn_df took 146.41320014 seconds
# append_gn_df took 195.517437935 seconds
# append_gn_df took 91.819890976 seconds
# append_gn_df took 104.841881037 seconds
# append_gn_df took 82.6004371643 seconds
# append_gn_df took 85.0309300423 seconds
# chunk_gn_df took 1234.32447505 seconds

# %%
full_songs13999 = chunk_gn_df(songs, 13000, 14000)
# Out:
# append_gn_df took 110.27683115 seconds
# append_gn_df took 92.056000948 seconds
# append_gn_df took 91.6379680634 seconds
# append_gn_df took 92.28464818 seconds
# append_gn_df took 109.537946939 seconds
# append_gn_df took 99.7420189381 seconds
# append_gn_df took 90.7187151909 seconds
# append_gn_df took 99.281733036 seconds
# append_gn_df took 104.241221905 seconds
# Must query with at least one field (artist, album, track, toc)
# append_gn_df took 125.22577405 seconds
# chunk_gn_df took 1016.37598181 seconds

# %%
full_songs14999 = chunk_gn_df(songs, 14000, 15000)
# Out:
# append_gn_df took 102.279052973 seconds
# append_gn_df took 149.364710808 seconds
# append_gn_df took 98.630658865 seconds
# append_gn_df took 93.2556109428 seconds
# append_gn_df took 138.696675062 seconds
# append_gn_df took 105.947779894 seconds
# append_gn_df took 84.4272220135 seconds
# append_gn_df took 91.7955269814 seconds
# append_gn_df took 104.516112804 seconds
# append_gn_df took 97.0090000629 seconds
# chunk_gn_df took 1067.31919789 seconds

# %%
full_songs15999 = chunk_gn_df(songs, 15000, 16000)
# Out:
# append_gn_df took 88.1784000397 seconds
# append_gn_df took 186.100250006 seconds
# append_gn_df took 133.599490166 seconds
# append_gn_df took 106.875953197 seconds
# append_gn_df took 92.7605168819 seconds
# append_gn_df took 117.334963083 seconds
# append_gn_df took 92.7208259106 seconds
# append_gn_df took 80.0384938717 seconds
# append_gn_df took 82.366686821 seconds
# append_gn_df took 66.072042942 seconds
# chunk_gn_df took 1047.44817519 seconds

# %%
full_songs16999 = chunk_gn_df(songs, 16000, 17000)
# Out:
# append_gn_df took 68.4800598621 seconds
# append_gn_df took 89.0547070503 seconds
# append_gn_df took 76.2554938793 seconds
# append_gn_df took 72.9623069763 seconds
# append_gn_df took 83.4721598625 seconds
# append_gn_df took 83.3267250061 seconds
# append_gn_df took 68.4833159447 seconds
# append_gn_df took 75.4022490978 seconds
# append_gn_df took 69.1183638573 seconds
# append_gn_df took 70.489814043 seconds
# chunk_gn_df took 758.437319994 seconds

# %%
full_songs17999 = chunk_gn_df(songs, 17000, 18000)
# Out:
# append_gn_df took 65.9987528324 seconds
# append_gn_df took 81.4038321972 seconds
# append_gn_df took 76.6291849613 seconds
# append_gn_df took 77.9058899879 seconds
# append_gn_df took 75.1371262074 seconds
# append_gn_df took 72.6422510147 seconds
# append_gn_df took 78.9188940525 seconds
# append_gn_df took 71.4597859383 seconds
# append_gn_df took 68.2057061195 seconds
# append_gn_df took 79.3313319683 seconds
# chunk_gn_df took 749.036851168 seconds

# %%
full_songs18999 = chunk_gn_df(songs, 18000, 19000)
# Out:
# append_gn_df took 134.369413853 seconds
# append_gn_df took 71.921598196 seconds
# append_gn_df took 82.494289875 seconds
# append_gn_df took 80.0985100269 seconds
# append_gn_df took 85.3357758522 seconds
# append_gn_df took 81.140155077 seconds
# append_gn_df took 82.5929679871 seconds
# append_gn_df took 71.8430140018 seconds
# Must query with at least one field (artist, album, track, toc)
# append_gn_df took 77.491494894 seconds
# append_gn_df took 73.9180419445 seconds
# chunk_gn_df took 842.593214035 seconds

# %%
full_songs19999 = chunk_gn_df(songs, 19000, 20000)
# Out:
# append_gn_df took 79.8324451447 seconds
# append_gn_df took 74.6913099289 seconds
# append_gn_df took 75.8829219341 seconds
# append_gn_df took 74.6354169846 seconds
# append_gn_df took 69.8141829967 seconds
# append_gn_df took 72.1624469757 seconds
# append_gn_df took 93.358782053 seconds
# append_gn_df took 71.6024250984 seconds
# append_gn_df took 69.3719408512 seconds
# append_gn_df took 70.4650909901 seconds
# chunk_gn_df took 753.183333158 seconds

# %%
full_songs20999 = chunk_gn_df(songs, 20000, 21000)
# Out:
# append_gn_df took 75.2547709942 seconds
# append_gn_df took 94.6666181087 seconds
# append_gn_df took 68.4411761761 seconds
# append_gn_df took 79.5312569141 seconds
# append_gn_df took 78.9820671082 seconds
# append_gn_df took 77.2299990654 seconds
# append_gn_df took 78.7224521637 seconds
# append_gn_df took 73.3751819134 seconds
# append_gn_df took 63.038287878 seconds
# append_gn_df took 78.0099339485 seconds
# chunk_gn_df took 768.634967089 seconds

# %%
full_songs21999 = chunk_gn_df(songs, 21000, 22000)
# Out:
# append_gn_df took 76.02511096 seconds
# append_gn_df took 78.6484959126 seconds
# append_gn_df took 78.8567829132 seconds
# append_gn_df took 75.5170691013 seconds
# append_gn_df took 74.2776551247 seconds
# append_gn_df took 77.606345892 seconds
# append_gn_df took 75.952696085 seconds
# append_gn_df took 76.0307929516 seconds
# append_gn_df took 93.7007489204 seconds
# append_gn_df took 66.8212759495 seconds
# chunk_gn_df took 774.803480864 seconds

# %%
full_songs22999 = chunk_gn_df(songs, 22000, 23000)
# Out:
# append_gn_df took 71.0597381592 seconds
# append_gn_df took 71.5488610268 seconds
# append_gn_df took 79.8974308968 seconds
# append_gn_df took 77.8238909245 seconds
# append_gn_df took 74.2301619053 seconds
# append_gn_df took 79.7944989204 seconds
# append_gn_df took 77.3801560402 seconds
# append_gn_df took 74.3855559826 seconds
# append_gn_df took 75.037225008 seconds
# append_gn_df took 90.1520750523 seconds
# chunk_gn_df took 772.704972029 seconds

# %%
full_songs23999 = chunk_gn_df(songs, 23000, 24000)
# Out:
# append_gn_df took 80.5861279964 seconds
# append_gn_df took 76.774463892 seconds
# append_gn_df took 67.6875209808 seconds
# append_gn_df took 80.0155110359 seconds
# append_gn_df took 76.2862389088 seconds
# append_gn_df took 76.028192997 seconds
# append_gn_df took 84.122674942 seconds
# append_gn_df took 67.9391460419 seconds
# append_gn_df took 73.0469720364 seconds
# append_gn_df took 71.1367211342 seconds
# chunk_gn_df took 755.017567873 seconds

# %%
full_songs24999 = chunk_gn_df(songs, 24000, 25000)
# Out:
# append_gn_df took 75.6429240704 seconds
# append_gn_df took 89.7353980541 seconds
# append_gn_df took 81.5058760643 seconds
# append_gn_df took 83.1520318985 seconds
# append_gn_df took 75.0766859055 seconds
# append_gn_df took 78.1087810993 seconds
# append_gn_df took 73.210572958 seconds
# append_gn_df took 78.4695570469 seconds
# append_gn_df took 71.3715658188 seconds
# append_gn_df took 67.5516898632 seconds
# chunk_gn_df took 775.238777161 seconds

# %%
full_songs25999 = chunk_gn_df(songs, 25000)

# %%
def load_pickles(start, stop):
    df = pd.DataFrame([])
    for i in range(start, stop, 1000):
        df = df.append(pd.read_pickle('data/full_songs_df_'+str(i)+'.pkl'), ignore_index=True)
    return df

# %%
full_songs_most = load_pickles(999, 24999)

# %%
full_songs_all = full_songs_most.append(pd.read_pickle('data/full_songs_df_25899.pkl'), ignore_index=True)

# %% [markdown]
# ### Load Pickle Point

# %%
full_songs_all.to_pickle('data/master_songs.pkl')

# %%
full_songs_all = pd.read_pickle('data/master_songs.pkl')

# %%
full_songs_all.head(10)
# Out:
#                                            artist explicit  \
# 0                                         Nirvana    False
# 1  The Presidents Of The United States Of America    False
# 2                                Stanton Warriors    False
# 3                               Natalie Marchenko    False
# 4                                           Robyn    False
# 5                                       Pearl Jam    False
# 6                                        Sam Hunt    False
# 7                                   George Carlin    False
# 8                                        Kaya May    False
# 9                                         Notaker    False
#
#                        id  popularity  \
# 0  3FUsMXBxA4V7eUwQ7B0HQO          48
# 1  2JdzB67NvIa90K4gEZPLeX          58
# 2  0zXLMZUCYZCx8Bq4jCr174          30
# 3  14w7n7gi635VCb5f7t2OQ5          37
# 4  01NJd6s7Kyn6NSsPp503sh          28
# 5  6qgpO647NPBUvBkm56vV7d           5
# 6  3wx2kQWPn9p5UppQbNhPAk          67
# 7  5DuxYjcuebFPontojL1NEE           0
# 8  4eg3wsiTrPa7KpwVai2VY7          56
# 9  341ShRaeysVdxLetlI391K          56
#
#                                                title  energy liveness  \
# 0                                          Love Buzz   0.885    0.169
# 1                                               Lump   0.873    0.165
# 2                                           So Sweet   0.936    0.118
# 3            License To Chill - Pacha Sax Lounge RMX   0.511     0.24
# 4            Be Mine! - Live At The Cherrytree House   0.249    0.114
# 5                                              Black   0.548    0.179
# 6                                 Leave The Night On   0.953    0.349
# 7                                       War Pictures   0.546    0.147
# 8  Hands to Myself, Love Yourself, Perfect (Acous...   0.445    0.113
# 9                                           Infinite   0.669    0.108
#
#      tempo speechiness  acousticness   ...   artist_type_2  \
# 0  138.153      0.0354      0.000032   ...      Male Group
# 1  142.726      0.0386      0.004680   ...      Male Group
# 2  127.997      0.0425      0.000531   ...        Male Duo
# 3  171.963      0.0302      0.262000   ...             NaN
# 4  116.599      0.0451      0.955000   ...          Female
# 5   76.020      0.0287      0.294000   ...      Male Group
# 6  171.971      0.0624      0.099600   ...            Male
# 7   72.940       0.961      0.921000   ...            Male
# 8  110.056        0.05      0.057500   ...             NaN
# 9   99.987      0.0483      0.093700   ...             NaN
#
#               genre_1                 genre_2               genre_3  \
# 0  Alternative & Punk             Alternative                Grunge
# 1  Alternative & Punk             Alternative       Alternative Pop
# 2         Electronica                  Techno             Breakbeat
# 3                 Pop          Easy Listening  Other Easy Listening
# 4         Electronica  Electronica Mainstream       Pop Electronica
# 5  Alternative & Punk             Alternative                Grunge
# 6         Traditional                 Country  Contemporary Country
# 7               Other                  Comedy                Comedy
# 8                 Pop             Western Pop             Pop Vocal
# 9         Electronica            Dance & Club            Club Dance
#
#                                          gnid      mood_1  \
# 0    5007273-06983AE0CA94A42592A86F999A523B41    Brooding
# 1    7176919-C893DAE82E18906A0C45F2D6651DF095  Aggressive
# 2  542968754-3A3DE9DCC8AACF9DE2F055187073DCA2  Energizing
# 3  212605678-5823A53026929EE7380477A9D3DCD697         NaN
# 4  176433014-A2FF98AC415031B8A67464F3DED3BC22    Romantic
# 5   17527306-1F01011247D0A98978073E66BF4D5597    Brooding
# 6  459278920-F9806BD4AFF4B5DC038D6D65E70C0B6C    Yearning
# 7    4965187-7F868B4D3F7D16781A583E8E222EF876       Other
# 8  604743990-4B9A5237E117F5CE9E8506362D53C1D9    Brooding
# 9  625141650-9A245193045FB288D1785D87C9D94308     Excited
#
#                    mood_2       tempo_1      tempo_2 tempo_3
# 0    Alienated / Brooding  Medium Tempo       Medium     60s
# 1        Aggressive Power    Fast Tempo         Fast    140s
# 2           Abstract Beat  Medium Tempo  Medium Fast    120s
# 3                     NaN           NaN          NaN     NaN
# 4       Heartfelt Passion  Medium Tempo       Medium     70s
# 5  Evocative / Intriguing  Medium Tempo       Medium     70s
# 6   Sensitive / Exploring  Medium Tempo       Medium     80s
# 7                     NaN    Slow Tempo       Static       0
# 8         Dreamy Brooding  Medium Tempo  Medium Slow     50s
# 9         Euphoric Energy  Medium Tempo  Medium Fast    100s
#
# [10 rows x 35 columns]

# %%
full_songs_all.count(axis=0)
# Out:
# artist              24567
# explicit            24567
# id                  24567
# popularity          24567
# title               24567
# energy              24567
# liveness            24561
# tempo               24567
# speechiness         24531
# acousticness        24567
# instrumentalness    24566
# time_signature      24531
# danceability        24531
# key                 24567
# duration_ms         24567
# loudness            24567
# valence             24529
# mode                24567
# artist_era_1        20782
# artist_era_2         8151
# artist_origin_1     20791
# artist_origin_2     20769
# artist_origin_3     15260
# artist_origin_4     10986
# artist_type_1       20785
# artist_type_2       20744
# genre_1             24354
# genre_2             24354
# genre_3             24354
# gnid                24567
# mood_1              21500
# mood_2              21059
# tempo_1             21499
# tempo_2             21499
# tempo_3             21499
# dtype: int64
